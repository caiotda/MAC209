# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import glob
"""
names = []
for file in glob.glob("*.csv"):   #armazena o titulo de cada arquivo em uma lista
    names.append(file)
i = 0
for i in range(len(names)):
"""
tbl = pd.read_csv("2019-05-2411.12.01.csv")
tbl.head()
fig = plt.figure(figsize=(32,4))
plt.subplot(131)
plt.plot(tbl["time"], tbl["wz"])
plt.show()

# %%
tbl = pd.read_csv("2019-05-2412.00.53.csv")
tbl.head()
fig = plt.figure(figsize=(32,4))
plt.subplot(131)
plt.plot(tbl["time"], tbl["wz"])
plt.show()
